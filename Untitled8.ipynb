# %% [markdown]
# ##### Programming Project 1
# Nick Komlanc

# %%
from math import e #Euler's number

# %%
Population=89000000
r=.0012
from math import e #Euler's number
Pop=89000000*e**(num+1*r)
def display_menu():
    print("================================================================")
print("================================================================")
print ("Population Growth")
print("================================================================")
print()
print ("We started with 89,000,000 people")
print()
print("+----------+----------------------------+-----------------------------------------------+")
print(" Year\t\t\tPopulation\t\tApproximate Increase from Previous Year")
print("+----------+----------------------------+-----------------------------------------------+")
print("|          |                            |                                               |")
for num in range(35):   
        print("|     ", num+1,"  |       ", 89000000*e**(num+1*r),"  |      ", 89000000*e**(num+1*r)-8900000,"                 |")
# Out:
# ...
# Population Growth
# ...
#
# We started with 89,000,000 people
#
# +----------+----------------------------+-----------------------------------------------+
#  Year			Population		Approximate Increase from Previous Year
# +----------+----------------------------+-----------------------------------------------+
# |          |                            |                                               |
# |      1   |        89106864.10563968   |       80206864.10563968                  |
# |      2   |        242217569.48932996   |       233317569.48932996                  |
# |      3   |        658415617.6763614   |       649515617.6763614                  |
# |      4   |        1789759209.1032913   |       1780859209.1032913                  |
# |      5   |        4865069935.4227085   |       4856169935.4227085                  |
# |      6   |        13224631199.641972   |       13215731199.641972                  |
# ...
